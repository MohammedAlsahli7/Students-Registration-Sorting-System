# %%
# Generate a file with random data

n = 100
import random
import string
file = open("LabProject.txt","w")
letters = string.ascii_letters
midlist = []
claslist = []
finallist = []
abcslist = []
while len(midlist) != n:
    letters = string.digits
    mid = ''.join(random.choice(letters) for i in range(2))
    if float(mid) <=35 :
        midlist.append(float(mid))
        
while len(claslist) != n:
    letters = string.digits
    clas = ''.join(random.choice(letters) for i in range(2))
    if float(clas) <=25 :
        claslist.append(float(clas))
        
while len(finallist) != n:
    letters = string.digits
    final = ''.join(random.choice(letters) for i in range(2))
    if float(final) <=40 :
        finallist.append(float(final))
        
while len(abcslist) != n:
    letters = string.digits
    abcs = ''.join(random.choice(letters) for i in range(2))
    if float(abcs) <=15 :
        abcslist.append(abcs)
x = 0
for i in range(n):
    letters = string.digits
    file.write( ''.join(random.choice(letters) for i in range(9)) )
    
    letters = string.ascii_letters
    file.write(":"+''.join(random.choice(letters) for i in range(10))) 
    
    file.write(":"+abcslist[i])

    file.write(":"+str(midlist[i]))
    
    file.write(":"+str(claslist[i]))
    
    file.write(":"+str(finallist[i]))
    
    if x < n-1:
        file.write("\n")
    x+=1    

file.close()

# %%
file = open("LabProject.txt")
for i in file:
    print(i,end="")
    j = i.strip().split(":")
    print(j)
    print(len(j))
# Out:
# 255916426:NlmAygiIoT:06:26.0:12.0:9.0
# ['255916426', 'NlmAygiIoT', '06', '26.0', '12.0', '9.0']
# 6
# 236290994:JxabvaOCLX:15:30.0:22.0:31.0
# ['236290994', 'JxabvaOCLX', '15', '30.0', '22.0', '31.0']
# 6
# 447675087:CGhvyzpxCZ:14:15.0:25.0:0.0
# ['447675087', 'CGhvyzpxCZ', '14', '15.0', '25.0', '0.0']
# 6
# 210611351:fhjIfOHkUu:00:20.0:0.0:30.0
# ['210611351', 'fhjIfOHkUu', '00', '20.0', '0.0', '30.0']
# 6
# 610233138:osYwdhGwVC:06:26.0:7.0:1.0
# ['610233138', 'osYwdhGwVC', '06', '26.0', '7.0', '1.0']
# 6
# 334162570:uMNxPuwagr:02:7.0:17.0:17.0
# ['334162570', 'uMNxPuwagr', '02', '7.0', '17.0', '17.0']
# 6
# 067194349:nfqcIDloOY:01:25.0:23.0:4.0
# ['067194349', 'nfqcIDloOY', '01', '25.0', '23.0', '4.0']
# 6
# 095618440:rvJtKrbSIH:08:26.0:4.0:21.0
# ['095618440', 'rvJtKrbSIH', '08', '26.0', '4.0', '21.0']
# 6
# 308386855:wWGnEtWRiB:07:29.0:3.0:30.0
# ['308386855', 'wWGnEtWRiB', '07', '29.0', '3.0', '30.0']
# 6
# 689723148:cSSwiHsHqF:05:5.0:10.0:19.0
# ['689723148', 'cSSwiHsHqF', '05', '5.0', '10.0', '19.0']
# 6
# 128397904:vqAJhKVYTc:10:8.0:5.0:32.0
# ['128397904', 'vqAJhKVYTc', '10', '8.0', '5.0', '32.0']
# 6
# 297531136:twxPxHDBMt:07:18.0:13.0:2.0
# ['297531136', 'twxPxHDBMt', '07', '18.0', '13.0', '2.0']
# 6
# 603420706:KhsRacmTjd:09:9.0:15.0:10.0
# ['603420706', 'KhsRacmTjd', '09', '9.0', '15.0', '10.0']
# 6
# 949067064:bqtQkNKuWu:14:5.0:3.0:21.0
# ['949067064', 'bqtQkNKuWu', '14', '5.0', '3.0', '21.0']
# 6
# 549019599:nBRkyJQkae:10:21.0:3.0:8.0
# ['549019599', 'nBRkyJQkae', '10', '21.0', '3.0', '8.0']
# 6
# 370221674:DjqEyoNbpN:05:16.0:19.0:32.0
# ['370221674', 'DjqEyoNbpN', '05', '16.0', '19.0', '32.0']
# 6
# 313012126:RjAQDfFhQI:11:28.0:19.0:25.0
# ['313012126', 'RjAQDfFhQI', '11', '28.0', '19.0', '25.0']
# 6
# 142385363:zQqNdyNYfq:09:3.0:23.0:36.0
# ['142385363', 'zQqNdyNYfq', '09', '3.0', '23.0', '36.0']
# 6
# 880646919:tOVYvOcrrW:05:4.0:7.0:17.0
# ['880646919', 'tOVYvOcrrW', '05', '4.0', '7.0', '17.0']
# 6
# 363609402:wuvTFBjjhB:11:15.0:4.0:40.0
# ['363609402', 'wuvTFBjjhB', '11', '15.0', '4.0', '40.0']
# 6
# 276986659:QltpVpfOXO:14:14.0:15.0:31.0
# ['276986659', 'QltpVpfOXO', '14', '14.0', '15.0', '31.0']
# 6
# 491061433:oiilRJDpqK:05:7.0:18.0:15.0
# ['491061433', 'oiilRJDpqK', '05', '7.0', '18.0', '15.0']
# 6
# 564038598:GbDeFBetLS:13:31.0:17.0:22.0
# ['564038598', 'GbDeFBetLS', '13', '31.0', '17.0', '22.0']
# 6
# 868289585:dXMQCfnTko:04:21.0:21.0:32.0
# ['868289585', 'dXMQCfnTko', '04', '21.0', '21.0', '32.0']
# 6
# 668918231:QLXYtVUAqN:13:6.0:22.0:36.0
# ['668918231', 'QLXYtVUAqN', '13', '6.0', '22.0', '36.0']
# 6
# 079345832:oYZEmcNAlf:08:11.0:15.0:1.0
# ['079345832', 'oYZEmcNAlf', '08', '11.0', '15.0', '1.0']
# 6
# 674094119:xzWCkPNNli:12:1.0:23.0:17.0
# ['674094119', 'xzWCkPNNli', '12', '1.0', '23.0', '17.0']
# 6
# 483720286:guLFVsAfGs:13:34.0:0.0:27.0
# ['483720286', 'guLFVsAfGs', '13', '34.0', '0.0', '27.0']
# 6
# 277171243:sqFyMlmEeo:00:14.0:25.0:38.0
# ['277171243', 'sqFyMlmEeo', '00', '14.0', '25.0', '38.0']
# 6
# 467984376:pdTsLVMmEs:08:1.0:23.0:13.0
# ['467984376', 'pdTsLVMmEs', '08', '1.0', '23.0', '13.0']
# 6
# 192940705:irTOJlfPms:14:17.0:6.0:35.0
# ['192940705', 'irTOJlfPms', '14', '17.0', '6.0', '35.0']
# 6
# 787664151:ffTvvWAvPZ:03:3.0:11.0:37.0
# ['787664151', 'ffTvvWAvPZ', '03', '3.0', '11.0', '37.0']
# 6
# 299696667:UoVtlxosPp:00:2.0:10.0:4.0
# ['299696667', 'UoVtlxosPp', '00', '2.0', '10.0', '4.0']
# 6
# 921696397:hZDuLqHxAE:03:16.0:1.0:39.0
# ['921696397', 'hZDuLqHxAE', '03', '16.0', '1.0', '39.0']
# 6
# 570910504:MiqZLvdpJB:08:8.0:0.0:34.0
# ['570910504', 'MiqZLvdpJB', '08', '8.0', '0.0', '34.0']
# 6
# 591675462:xQiSVjeTik:01:21.0:7.0:19.0
# ['591675462', 'xQiSVjeTik', '01', '21.0', '7.0', '19.0']
# 6
# 017687773:fWkkFTrCcX:13:34.0:15.0:11.0
# ['017687773', 'fWkkFTrCcX', '13', '34.0', '15.0', '11.0']
# 6
# 602123993:wxOhxWuZlQ:04:0.0:10.0:13.0
# ['602123993', 'wxOhxWuZlQ', '04', '0.0', '10.0', '13.0']
# 6
# 636476864:gMKYUPssvD:13:14.0:15.0:10.0
# ['636476864', 'gMKYUPssvD', '13', '14.0', '15.0', '10.0']
# 6
# 792070989:wJyexxNJbz:08:32.0:2.0:16.0
# ['792070989', 'wJyexxNJbz', '08', '32.0', '2.0', '16.0']
# 6
# 765660952:miIiFuaDhQ:00:8.0:8.0:24.0
# ['765660952', 'miIiFuaDhQ', '00', '8.0', '8.0', '24.0']
# 6
# 265950926:YwiwClIqsY:01:11.0:16.0:28.0
# ['265950926', 'YwiwClIqsY', '01', '11.0', '16.0', '28.0']
# 6
# 346470087:ERbZeRkAxk:10:9.0:2.0:34.0
# ['346470087', 'ERbZeRkAxk', '10', '9.0', '2.0', '34.0']
# 6
# 129044109:KqRFVxcwtv:07:11.0:8.0:0.0
# ['129044109', 'KqRFVxcwtv', '07', '11.0', '8.0', '0.0']
# 6
# 320850486:KRelangZsi:06:2.0:18.0:16.0
# ['320850486', 'KRelangZsi', '06', '2.0', '18.0', '16.0']
# 6
# 414793376:GSyRsfnpkm:02:12.0:13.0:39.0
# ['414793376', 'GSyRsfnpkm', '02', '12.0', '13.0', '39.0']
# 6
# 153172804:zTJdZWgnhB:12:22.0:20.0:40.0
# ['153172804', 'zTJdZWgnhB', '12', '22.0', '20.0', '40.0']
# 6
# 743009486:cXHceezYJO:10:28.0:16.0:29.0
# ['743009486', 'cXHceezYJO', '10', '28.0', '16.0', '29.0']
# 6
# 295315069:iNtTHNfPbj:14:5.0:13.0:28.0
# ['295315069', 'iNtTHNfPbj', '14', '5.0', '13.0', '28.0']
# 6
# 078030900:hFspMLfrmQ:09:17.0:15.0:1.0
# ['078030900', 'hFspMLfrmQ', '09', '17.0', '15.0', '1.0']
# 6
# 638713571:VqVqMqQwjg:03:32.0:0.0:32.0
# ['638713571', 'VqVqMqQwjg', '03', '32.0', '0.0', '32.0']
# 6
# 618840551:IhiGgftITx:13:4.0:25.0:35.0
# ['618840551', 'IhiGgftITx', '13', '4.0', '25.0', '35.0']
# 6
# 773638393:fXlwTGuZIF:04:17.0:22.0:15.0
# ['773638393', 'fXlwTGuZIF', '04', '17.0', '22.0', '15.0']
# 6
# 909657906:CJJDqJatzH:15:34.0:11.0:39.0
# ['909657906', 'CJJDqJatzH', '15', '34.0', '11.0', '39.0']
# 6
# 451258971:sJTFGWuyyn:13:21.0:8.0:29.0
# ['451258971', 'sJTFGWuyyn', '13', '21.0', '8.0', '29.0']
# 6
# 903471795:ykoRiJsgcG:08:33.0:13.0:26.0
# ['903471795', 'ykoRiJsgcG', '08', '33.0', '13.0', '26.0']
# 6
# 908100350:YkjbHvjXej:05:4.0:3.0:20.0
# ['908100350', 'YkjbHvjXej', '05', '4.0', '3.0', '20.0']
# 6
# 619328697:gtAdiZshRu:11:23.0:24.0:16.0
# ['619328697', 'gtAdiZshRu', '11', '23.0', '24.0', '16.0']
# 6
# 713351919:uYxTjYtvul:00:3.0:17.0:0.0
# ['713351919', 'uYxTjYtvul', '00', '3.0', '17.0', '0.0']
# 6
# 381743254:bnbUQkufiL:12:14.0:22.0:27.0
# ['381743254', 'bnbUQkufiL', '12', '14.0', '22.0', '27.0']
# 6
# 883782202:uhtlWQCuzJ:09:17.0:3.0:38.0
# ['883782202', 'uhtlWQCuzJ', '09', '17.0', '3.0', '38.0']
# 6
# 539167384:GhXAzXHgDK:06:7.0:17.0:17.0
# ['539167384', 'GhXAzXHgDK', '06', '7.0', '17.0', '17.0']
# 6
# 696832313:mehCDsBQnv:05:10.0:15.0:40.0
# ['696832313', 'mehCDsBQnv', '05', '10.0', '15.0', '40.0']
# 6
# 075169169:OfrqgZBWFD:00:34.0:10.0:5.0
# ['075169169', 'OfrqgZBWFD', '00', '34.0', '10.0', '5.0']
# 6
# 215187991:NfMZSJyKee:01:0.0:14.0:27.0
# ['215187991', 'NfMZSJyKee', '01', '0.0', '14.0', '27.0']
# 6
# 748245044:KjUGySqXvG:15:9.0:3.0:9.0
# ['748245044', 'KjUGySqXvG', '15', '9.0', '3.0', '9.0']
# 6
# 914000607:MxCduVIkEo:03:23.0:9.0:1.0
# ['914000607', 'MxCduVIkEo', '03', '23.0', '9.0', '1.0']
# 6
# 776064011:nWdjvKXsGf:08:19.0:10.0:19.0
# ['776064011', 'nWdjvKXsGf', '08', '19.0', '10.0', '19.0']
# 6
# 245334998:ALkzsUpYyT:13:28.0:14.0:10.0
# ['245334998', 'ALkzsUpYyT', '13', '28.0', '14.0', '10.0']
# 6
# 649531395:bakoWxDDIV:15:10.0:3.0:31.0
# ['649531395', 'bakoWxDDIV', '15', '10.0', '3.0', '31.0']
# 6
# 101305520:krZxOERgFe:05:23.0:7.0:8.0
# ['101305520', 'krZxOERgFe', '05', '23.0', '7.0', '8.0']
# 6
# 708674530:lKxdpYHgUM:03:25.0:19.0:18.0
# ['708674530', 'lKxdpYHgUM', '03', '25.0', '19.0', '18.0']
# 6
# 863179576:tytmnmwUSq:12:24.0:0.0:15.0
# ['863179576', 'tytmnmwUSq', '12', '24.0', '0.0', '15.0']
# 6
# 191237282:gjihsmxcjA:09:8.0:17.0:29.0
# ['191237282', 'gjihsmxcjA', '09', '8.0', '17.0', '29.0']
# 6
# 425191652:oxOpsQidMc:04:19.0:3.0:10.0
# ['425191652', 'oxOpsQidMc', '04', '19.0', '3.0', '10.0']
# 6
# 526099280:bjGiBoQwiL:10:27.0:23.0:23.0
# ['526099280', 'bjGiBoQwiL', '10', '27.0', '23.0', '23.0']
# 6
# 272466507:FOdYBCzUFg:07:10.0:18.0:11.0
# ['272466507', 'FOdYBCzUFg', '07', '10.0', '18.0', '11.0']
# 6
# 082207881:nVCAWHRWav:10:14.0:1.0:18.0
# ['082207881', 'nVCAWHRWav', '10', '14.0', '1.0', '18.0']
# 6
# 346952215:MgrgFwlpBI:02:23.0:18.0:40.0
# ['346952215', 'MgrgFwlpBI', '02', '23.0', '18.0', '40.0']
# 6
# 382925167:jRVpAqHHtq:00:35.0:13.0:39.0
# ['382925167', 'jRVpAqHHtq', '00', '35.0', '13.0', '39.0']
# 6
# 566080215:eZBwNRIJqh:09:27.0:0.0:21.0
# ['566080215', 'eZBwNRIJqh', '09', '27.0', '0.0', '21.0']
# 6
# 062880437:VZVXDQtLdG:00:0.0:14.0:21.0
# ['062880437', 'VZVXDQtLdG', '00', '0.0', '14.0', '21.0']
# 6
# 215199874:KEpRUgbegd:00:0.0:21.0:19.0
# ['215199874', 'KEpRUgbegd', '00', '0.0', '21.0', '19.0']
# 6
# 137525272:ikjzgJAjLw:12:24.0:22.0:34.0
# ['137525272', 'ikjzgJAjLw', '12', '24.0', '22.0', '34.0']
# 6
# 907861192:hUSQxkGXXn:12:26.0:22.0:29.0
# ['907861192', 'hUSQxkGXXn', '12', '26.0', '22.0', '29.0']
# 6
# 543780590:WrGZMqtjql:06:34.0:25.0:4.0
# ['543780590', 'WrGZMqtjql', '06', '34.0', '25.0', '4.0']
# 6
# 547838914:oagAilLpSM:05:26.0:3.0:14.0
# ['547838914', 'oagAilLpSM', '05', '26.0', '3.0', '14.0']
# 6
# 088539050:iEFYZMjybp:10:12.0:2.0:1.0
# ['088539050', 'iEFYZMjybp', '10', '12.0', '2.0', '1.0']
# 6
# 151119839:yiCTFDZoTz:05:16.0:10.0:35.0
# ['151119839', 'yiCTFDZoTz', '05', '16.0', '10.0', '35.0']
# 6
# 694942635:erhVSRdZDF:10:8.0:5.0:24.0
# ['694942635', 'erhVSRdZDF', '10', '8.0', '5.0', '24.0']
# 6
# 712191840:tJCJDDWppx:10:7.0:8.0:20.0
# ['712191840', 'tJCJDDWppx', '10', '7.0', '8.0', '20.0']
# 6
# 626917446:nENxVEFsud:03:16.0:8.0:38.0
# ['626917446', 'nENxVEFsud', '03', '16.0', '8.0', '38.0']
# 6
# 525448804:SnYUlflZkB:11:15.0:6.0:18.0
# ['525448804', 'SnYUlflZkB', '11', '15.0', '6.0', '18.0']
# 6
# 479010370:ehimCaPbei:04:23.0:18.0:4.0
# ['479010370', 'ehimCaPbei', '04', '23.0', '18.0', '4.0']
# 6
# 448653503:zZgNWsEoiI:11:16.0:24.0:24.0
# ['448653503', 'zZgNWsEoiI', '11', '16.0', '24.0', '24.0']
# 6
# 514152184:BSjmGaPsvo:15:17.0:15.0:1.0
# ['514152184', 'BSjmGaPsvo', '15', '17.0', '15.0', '1.0']
# 6
# 746843600:rzSohTSzfA:00:1.0:16.0:20.0
# ['746843600', 'rzSohTSzfA', '00', '1.0', '16.0', '20.0']
# 6
# 987921611:tcicByUBEH:08:0.0:11.0:0.0
# ['987921611', 'tcicByUBEH', '08', '0.0', '11.0', '0.0']
# 6
# 687023857:tHuLCMrfbt:12:32.0:7.0:6.0
# ['687023857', 'tHuLCMrfbt', '12', '32.0', '7.0', '6.0']
# 6
# 111111111:mmhVIIINpF:07:18.0:20.0:29.0['111111111', 'mmhVIIINpF', '07', '18.0', '20.0', '29.0']
# 6
